# %%
import polars as pl

# %%
# Load Spotify Dataset to Polars Dataframe (lazy loading API bc large datasets)
spotify_df = pl.scan_csv('hf://datasets/maharshipandya/spotify-tracks-dataset/dataset.csv').select(["track_id", "artists", "track_name"])

# %%
# Load Chord progressions dataset to Polars Dataframe (lazy loading API bc large datasets)
chord_df = pl.scan_csv('hf://datasets/ailsntua/Chordonomicon/chordonomicon_v2.csv').select(["chords", "genres", "spotify_song_id"])

# %%
# Genius lyrics dataset to Polars Dataframe (lazy loading API bc large datasets)
genius_df = pl.scan_csv('hf://datasets/sebastiandizon/genius-song-lyrics/song_lyrics 2.csv').select(["title", "artist", "lyrics"])

# %%
spotify_df = spotify_df.drop_nulls(subset=["track_id", "track_name", "artists"])

# %%
chord_df = chord_df.drop_nulls(subset=["spotify_song_id", "chords", "genres"])

# %%
genius_df = genius_df.drop_nulls(subset=["title", "artist", "lyrics"])

# %%
def normalize_title(col_name: str):
    return (
        pl.col(col_name)
        .str.to_lowercase()
        .str.replace_all(r"[\(\[].*?[\)\]]", "")
        .str.replace_all(r"[^\w\s]", "")
        .str.replace_all(r"\s+", " ")
        .str.strip_chars()
    )

# %%
def normalize_artist(col_name: str):
    return (
        pl.col(col_name)
        .str.to_lowercase()
        .str.replace_all(r"[\(\[].*?[\)\]]", "")
        .str.split(";").list.first()
        .str.replace_all(r"[^\w\s]", "")
        .str.strip_chars()
    )

# %%
spotify_df = spotify_df.with_columns(
    normalize_title("track_name").alias("norm_track_name"),
    normalize_artist("artists").alias("norm_artists")
)

# %%
genius_df = genius_df.with_columns(
    normalize_title("title").alias("title_norm"),
    normalize_artist("artist").alias("artist_norm")  # no split needed, single artist
)

# %%
out1 = chord_df.join(
    spotify_df,
    left_on="spotify_song_id",
    right_on="track_id",
    how="inner"
)

# %%
final = out1.join(
    genius_df,
    left_on=["norm_track_name", "norm_artists"],
    right_on=["title_norm", "artist_norm"],
    how="inner"
)

# %%
print(final.explain())
# Out:
# INNER JOIN:
# LEFT PLAN ON: [col("norm_track_name"), col("norm_artists")]
#   INNER JOIN:
#   LEFT PLAN ON: [col("spotify_song_id")]
#     Csv SCAN [https://huggingface.co/datasets/ailsntua/Chordonomicon/resolve/main/chordonomicon_v2.csv]
#     PROJECT 3/10 COLUMNS
#     SELECTION: [([(col("genres").is_not_null()) & (col("chords").is_not_null())]) & (col("spotify_song_id").is_not_null())]
#     ESTIMATED ROWS: 559563
#   RIGHT PLAN ON: [col("track_id")]
#      WITH_COLUMNS:
#      [col("track_name").str.to_lowercase().str.replace(["[\(\[].*?[\)\]]", ""]).str.replace(["[^\w\s]", ""]).str.replace(["\s+", " "]).str.strip_chars([null]).alias("norm_track_name"), col("artists").str.to_lowercase().str.replace(["[\(\[].*?[\)\]]", ""]).str.split([";"]).list.get([dyn int: 0]).str.replace(["[^\w\s]", ""]).str.strip_chars([null]).alias("norm_artists")]
#       Csv SCAN [https://huggingface.co/datasets/maharshipandya/spotify-tracks-dataset/resolve/main/dataset.csv]
#       PROJECT 3/21 COLUMNS
#       SELECTION: [([(col("artists").is_not_null()) & (col("track_id").is_not_null())]) & (col("track_name").is_not_null())]
#       ESTIMATED ROWS: 116216
#   END INNER JOIN
# RIGHT PLAN ON: [col("title_norm"), col("artist_norm")]
#    WITH_COLUMNS:
#    [col("title").str.to_lowercase().str.replace(["[\(\[].*?[\)\]]", ""]).str.replace(["[^\w\s]", ""]).str.replace(["\s+", " "]).str.strip_chars([null]).alias("title_norm"), col("artist").str.to_lowercase().str.replace(["[\(\[].*?[\)\]]", ""]).str.split([";"]).list.get([dyn int: 0]).str.replace(["[^\w\s]", ""]).str.strip_chars([null]).alias("artist_norm")]
#     Csv SCAN [https://huggingface.co/datasets/sebastiandizon/genius-song-lyrics/resolve/main/song_lyrics%202.csv]
#     PROJECT 3/11 COLUMNS
#     SELECTION: [([(col("artist").is_not_null()) & (col("title").is_not_null())]) & (col("lyrics").is_not_null())]
#     ESTIMATED ROWS: 2436156
# END INNER JOIN

# %%
sample = final.head(5000).collect()

# %%
sample
# Out:
# shape: (5_000, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ chords    ┆ genres    ┆ spotify_s ┆ artists   ┆ … ┆ norm_arti ┆ title     ┆ artist    ┆ lyrics   │
# │ ---       ┆ ---       ┆ ong_id    ┆ ---       ┆   ┆ sts       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ str       ┆           ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ <intro_1> ┆ 'g funk'  ┆ 503OTo2dS ┆ Dr.       ┆ … ┆ dr dre    ┆ Still     ┆ Dr. Dre   ┆ [Produce │
# │ Bbmin     ┆ 'gangster ┆ qe7qk76rg ┆ Dre;Snoop ┆   ┆           ┆ D.R.E.    ┆           ┆ d by Dr. │
# │ Bbmin9    ┆ rap' 'hip ┆ sbep      ┆ Dogg      ┆   ┆           ┆           ┆           ┆ Dre,     │
# │ Fmin Bb…  ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Scott    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ St…      │
# │ <intro_1> ┆ 'g funk'  ┆ 503OTo2dS ┆ Dr.       ┆ … ┆ dr dre    ┆ Still     ┆ Dr. Dre   ┆ [Produce │
# │ Bbmin     ┆ 'gangster ┆ qe7qk76rg ┆ Dre;Snoop ┆   ┆           ┆ D.R.E.    ┆           ┆ d by Dr. │
# │ Bbmin9    ┆ rap' 'hip ┆ sbep      ┆ Dogg      ┆   ┆           ┆           ┆           ┆ Dre,     │
# │ Fmin Bb…  ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Scott    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ St…      │
# │ Dmin Gmin ┆ 'g funk'  ┆ 2zoobJFEB ┆ 2Pac      ┆ … ┆ 2pac      ┆ Hail Mary ┆ 2Pac      ┆ [Segue   │
# │ F Emin    ┆ 'gangster ┆ 9h15fjYjR ┆           ┆   ┆           ┆           ┆           ┆ from     │
# │ Dmin Gmin ┆ rap' 'hip ┆ d6oP      ┆           ┆   ┆           ┆           ┆           ┆ "Bomb    │
# │ F E…      ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ First"]  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ [In…     │
# │ <intro_1> ┆ 'g funk'  ┆ 1SWVDBtw6 ┆ Dr. Dre;E ┆ … ┆ dr dre    ┆ Whats the ┆ Dr. Dre   ┆ [Produce │
# │ Bmin Emin ┆ 'gangster ┆ h3tm9OehO ┆ minem;Xzi ┆   ┆           ┆ Differenc ┆           ┆ d by Dr. │
# │ D Fs Bmin ┆ rap' 'hip ┆ kDhv      ┆ bit       ┆   ┆           ┆ e         ┆           ┆ Dre &    │
# │ …         ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Mel-Man… │
# │ <intro_1> ┆ 'alternat ┆ 30oTS7bm0 ┆ Gang      ┆ … ┆ gang      ┆ Full Clip ┆ Gang      ┆ [Intro:  │
# │ C G Dmin  ┆ ive hip   ┆ aH3p7lqjE ┆ Starr     ┆   ┆ starr     ┆           ┆ Starr     ┆ DJ       │
# │ C G Dmin  ┆ hop'      ┆ Iu8q      ┆           ┆   ┆           ┆           ┆           ┆ Premier] │
# │ C …       ┆ 'conscio… ┆           ┆           ┆   ┆           ┆           ┆           ┆ Big L,   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ res…     │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ <intro_1> ┆ 'k-pop'   ┆ 60jFaQV7Z ┆ TWICE     ┆ … ┆ twice     ┆ TT        ┆ TWICE     ┆ [트와이  │
# │ Amin7     ┆ 'k-pop    ┆ 4boGC4ob5 ┆           ┆   ┆           ┆           ┆           ┆ 스 "TT"  │
# │ Gmaj7     ┆ girl      ┆ B5c6      ┆           ┆   ┆           ┆           ┆           ┆ 가사]    │
# │ <verse_1… ┆ group'    ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 'po…      ┆           ┆           ┆   ┆           ┆           ┆           ┆ [Verse   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1: Naye… │
# │ <intro_1> ┆ 'neo-psyc ┆ 3QaULt6mF ┆ Pond      ┆ … ┆ pond      ┆ Holding   ┆ Pond      ┆ What in  │
# │ B Ebmin   ┆ hedelic'  ┆ jXbmU1O8c ┆           ┆   ┆           ┆ Out for   ┆           ┆ the      │
# │ Dbmin Fs  ┆           ┆ hake      ┆           ┆   ┆           ┆ You       ┆           ┆ world    │
# │ B B…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ever     │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ made th… │
# │ <chorus_1 ┆ 'modern   ┆ 5w6B0sAH7 ┆ Barns     ┆ … ┆ barns     ┆ Fire      ┆ Barns     ┆ [Verse   │
# │ > Emin G  ┆ alternati ┆ XauCvMOAt ┆ Courtney  ┆   ┆ courtney  ┆           ┆ Courtney  ┆ 1]       │
# │ A Emin    ┆ ve rock'  ┆ plQj      ┆           ┆   ┆           ┆           ┆           ┆ Lonely   │
# │ <vers…    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ shadows  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ follo…   │
# │ Dsmin Cs  ┆ 'modern   ┆ 1Mf27cnAF ┆ Barns     ┆ … ┆ barns     ┆ Glitter   ┆ Barns     ┆ [Intro]  │
# │ Gs Dsmin  ┆ alternati ┆ 1Q6Ko83XT ┆ Courtney  ┆   ┆ courtney  ┆ Gold      ┆ Courtney  ┆ I am     │
# │ Cs Gs     ┆ ve rock'  ┆ M5d1      ┆           ┆   ┆           ┆           ┆           ┆ flesh    │
# │ Dsmin …   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ and I am │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ bo…      │
# │ Dsmin Cs  ┆ 'modern   ┆ 1Mf27cnAF ┆ Barns     ┆ … ┆ barns     ┆ Glitter   ┆ Barns     ┆ [Intro]  │
# │ Gs Dsmin  ┆ alternati ┆ 1Q6Ko83XT ┆ Courtney  ┆   ┆ courtney  ┆ Gold      ┆ Courtney  ┆ I am     │
# │ Cs Gs     ┆ ve rock'  ┆ M5d1      ┆           ┆   ┆           ┆           ┆           ┆ flesh    │
# │ Dsmin …   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ and I am │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ bo…      │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
final = final.collect()

# %%
final
# Out:
# shape: (9_322, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ chords    ┆ genres    ┆ spotify_s ┆ artists   ┆ … ┆ norm_arti ┆ title     ┆ artist    ┆ lyrics   │
# │ ---       ┆ ---       ┆ ong_id    ┆ ---       ┆   ┆ sts       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ str       ┆ str       ┆ str      │
# │           ┆           ┆ str       ┆           ┆   ┆ str       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ <intro_1> ┆ 'g funk'  ┆ 503OTo2dS ┆ Dr.       ┆ … ┆ dr dre    ┆ Still     ┆ Dr. Dre   ┆ [Produce │
# │ Bbmin     ┆ 'gangster ┆ qe7qk76rg ┆ Dre;Snoop ┆   ┆           ┆ D.R.E.    ┆           ┆ d by Dr. │
# │ Bbmin9    ┆ rap' 'hip ┆ sbep      ┆ Dogg      ┆   ┆           ┆           ┆           ┆ Dre,     │
# │ Fmin Bb…  ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Scott    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ St…      │
# │ <intro_1> ┆ 'g funk'  ┆ 503OTo2dS ┆ Dr.       ┆ … ┆ dr dre    ┆ Still     ┆ Dr. Dre   ┆ [Produce │
# │ Bbmin     ┆ 'gangster ┆ qe7qk76rg ┆ Dre;Snoop ┆   ┆           ┆ D.R.E.    ┆           ┆ d by Dr. │
# │ Bbmin9    ┆ rap' 'hip ┆ sbep      ┆ Dogg      ┆   ┆           ┆           ┆           ┆ Dre,     │
# │ Fmin Bb…  ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Scott    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ St…      │
# │ Dmin Gmin ┆ 'g funk'  ┆ 2zoobJFEB ┆ 2Pac      ┆ … ┆ 2pac      ┆ Hail Mary ┆ 2Pac      ┆ [Segue   │
# │ F Emin    ┆ 'gangster ┆ 9h15fjYjR ┆           ┆   ┆           ┆           ┆           ┆ from     │
# │ Dmin Gmin ┆ rap' 'hip ┆ d6oP      ┆           ┆   ┆           ┆           ┆           ┆ "Bomb    │
# │ F E…      ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ First"]  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ [In…     │
# │ <intro_1> ┆ 'g funk'  ┆ 1SWVDBtw6 ┆ Dr. Dre;E ┆ … ┆ dr dre    ┆ Whats the ┆ Dr. Dre   ┆ [Produce │
# │ Bmin Emin ┆ 'gangster ┆ h3tm9OehO ┆ minem;Xzi ┆   ┆           ┆ Differenc ┆           ┆ d by Dr. │
# │ D Fs Bmin ┆ rap' 'hip ┆ kDhv      ┆ bit       ┆   ┆           ┆ e         ┆           ┆ Dre &    │
# │ …         ┆ h…        ┆           ┆           ┆   ┆           ┆           ┆           ┆ Mel-Man… │
# │ <intro_1> ┆ 'alternat ┆ 30oTS7bm0 ┆ Gang      ┆ … ┆ gang      ┆ Full Clip ┆ Gang      ┆ [Intro:  │
# │ C G Dmin  ┆ ive hip   ┆ aH3p7lqjE ┆ Starr     ┆   ┆ starr     ┆           ┆ Starr     ┆ DJ       │
# │ C G Dmin  ┆ hop'      ┆ Iu8q      ┆           ┆   ┆           ┆           ┆           ┆ Premier] │
# │ C …       ┆ 'conscio… ┆           ┆           ┆   ┆           ┆           ┆           ┆ Big L,   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ res…     │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ <verse_1> ┆ 'indie    ┆ 5sixigDZ8 ┆ PmBata    ┆ … ┆ pmbata    ┆ ​i hate    ┆ PmBata    ┆ [Verse   │
# │ C Amin F  ┆ hip hop'  ┆ 6eDzCHXbf ┆           ┆   ┆           ┆ her boyfr ┆           ┆ 1]       │
# │ G C Amin  ┆ 'pixel'   ┆ zrDu      ┆           ┆   ┆           ┆ iends     ┆           ┆ She told │
# │ F …       ┆           ┆           ┆           ┆   ┆           ┆ face      ┆           ┆ me       │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ That     │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ her…     │
# │ <intro_1> ┆ 'sad      ┆ 0ZbghqrVh ┆ Powfu;KMa ┆ … ┆ powfu     ┆ ​draw you  ┆ Powfu     ┆ [Verse   │
# │ Dmaj7     ┆ lo-fi'    ┆ OtGom63oK ┆ ys        ┆   ┆           ┆ inside my ┆           ┆ 1]       │
# │           ┆ 'sad rap' ┆ xONU      ┆           ┆   ┆           ┆ book      ┆           ┆ I was    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ telling  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ her se…  │
# │ <intro_1> ┆ 'sad rap' ┆ 4kKhmIdFA ┆ MASN      ┆ … ┆ masn      ┆ Love Me   ┆ MASN      ┆ [Verse   │
# │ Amin F C  ┆           ┆ LmwCYrt90 ┆           ┆   ┆           ┆ For Me    ┆           ┆ 1]       │
# │ G <verse_ ┆           ┆ oWUW      ┆           ┆   ┆           ┆           ┆           ┆ Head in  │
# │ 1>…       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ the      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ clouds   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ w…       │
# │ <intro_1> ┆ 'sad rap' ┆ 4kKhmIdFA ┆ MASN      ┆ … ┆ masn      ┆ Love Me   ┆ MASN      ┆ [Verse   │
# │ Amin F C  ┆           ┆ LmwCYrt90 ┆           ┆   ┆           ┆ For Me    ┆           ┆ 1]       │
# │ G <verse_ ┆           ┆ oWUW      ┆           ┆   ┆           ┆           ┆           ┆ Head in  │
# │ 1>…       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ the      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ clouds   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ w…       │
# │ <intro_1> ┆ 'sad rap' ┆ 4kKhmIdFA ┆ MASN      ┆ … ┆ masn      ┆ Love Me   ┆ MASN      ┆ [Verse   │
# │ Amin F C  ┆           ┆ LmwCYrt90 ┆           ┆   ┆           ┆ For Me    ┆           ┆ 1]       │
# │ G <verse_ ┆           ┆ oWUW      ┆           ┆   ┆           ┆           ┆           ┆ Head in  │
# │ 1>…       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ the      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ clouds   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ w…       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
final.write_csv("final_dataset.csv")
